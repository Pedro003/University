# %% [markdown]
# # Considere o seguinte feature model.

# %%
from IPython.display import Image

# Display the image
Image("feature_model.jpg")

# %% [markdown]
# ## Pergunta 1
# Qual o número máximo de __core features__ que poderia ter acrescentando uma restrição adicional do tipo requires a este feature model
#
# __Resposta:__

# %% [markdown]
# ## Pergunta 2

# %% [markdown]
# Assumindo que a feature __Security__ é obrigatória quantas variantes existem?
#
# __Resposta:__
